# %% [markdown]
# # Food Production and Supply from 2004-2013

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import pandas_profiling as pp

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

# %% [markdown]
# profile =  pp.ProfileReport(f_supp)
# `
# profile.to_file("output.html")

# %%
f_prod = pd.read_csv('Africa Food Production (2004 - 2013).csv')
f_prod
# Out:
#         Country                Item  Year  Value
# 0       Algeria  Wheat and products  2004   2731
# 1       Algeria  Wheat and products  2005   2415
# 2       Algeria  Wheat and products  2006   2688
# 3       Algeria  Wheat and products  2007   2319
# 4       Algeria  Wheat and products  2008   1111
# ...         ...                 ...   ...    ...
# 23105  Zimbabwe         Crustaceans  2009      0
# 23106  Zimbabwe         Crustaceans  2010      0
# 23107  Zimbabwe         Crustaceans  2011      0
# 23108  Zimbabwe         Crustaceans  2012      0
# 23109  Zimbabwe         Crustaceans  2013      0
#
# [23110 rows x 4 columns]

# %%
f_supp = pd.read_csv('Africa Food Supply (2004 - 2013).csv')
f_supp
# Out:
#                          Country  Year  Value
# 0                        Algeria  2004   2987
# 1                        Algeria  2005   2958
# 2                        Algeria  2006   3047
# 3                        Algeria  2007   3041
# 4                        Algeria  2008   3048
# 5                        Algeria  2009   3110
# 6                        Algeria  2010   3142
# 7                        Algeria  2011   3217
# 8                        Algeria  2012   3272
# 9                        Algeria  2013   3296
# 10                        Angola  2004   2030
# 11                        Angola  2005   2077
# 12                        Angola  2006   2119
# 13                        Angola  2007   2173
# 14                        Angola  2008   2245
# 15                        Angola  2009   2303
# 16                        Angola  2010   2345
# 17                        Angola  2011   2407
# 18                        Angola  2012   2384
# ...

# %%
f_supp.Country.count()
# Out:
# 450

# %%
f_prod.groupby('Item')[['Value','Year']].min()
# Out:
#                                  Value  Year
# Item
# Alcohol, Non-Food                    2  2004
# Apples and products                  1  2004
# Aquatic Animals, Others              0  2004
# Aquatic Plants                       0  2004
# Bananas                              0  2004
# Barley and products                  0  2004
# Beans                                0  2004
# Beer                                 0  2004
# Beverages, Alcoholic                 0  2004
# Beverages, Fermented                 1  2004
# Bovine Meat                          0  2004
# Butter, Ghee                         0  2004
# Cassava and products                 0  2004
# Cephalopods                          0  2004
# Cereals, Other                       0  2004
# Citrus, Other                        0  2004
# Cloves                               1  2004
# Cocoa Beans and products             0  2004
# Coconut Oil                          0  2004
# Coconuts - Incl Copra                2  2004
# ...

# %%
c = f_prod.groupby(['Item','Year'])['Value'].sum().reset_index()
c
# Out:
#                   Item  Year  Value
# 0    Alcohol, Non-Food  2004    296
# 1    Alcohol, Non-Food  2005    332
# 2    Alcohol, Non-Food  2006    338
# 3    Alcohol, Non-Food  2007    370
# 4    Alcohol, Non-Food  2008    477
# ..                 ...   ...    ...
# 935               Yams  2009  45518
# 936               Yams  2010  51253
# 937               Yams  2011  54819
# 938               Yams  2012  59266
# 939               Yams  2013  60532
#
# [940 rows x 3 columns]

# %%
total_Item = c.groupby(['Item'])['Value'].sum().reset_index()

# %%
f_supp.Country.value_counts().sum()
# Out:
# 450

# %%
f_prod.Country.value_counts().sum()
# Out:
# 23110

# %%
f_prod.Country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Congo', "Cote d'Ivoire", 'Djibouti', 'Egypt', 'Ethiopia', 'Gabon',
#        'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
#        'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger',
#        'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal',
#        'Sierra Leone', 'South Africa', 'Sudan', 'Swaziland', 'Togo',
#        'Tunisia', 'Uganda', 'United Republic of Tanzania', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
f_supp.Country.unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Congo', "Cote d'Ivoire", 'Djibouti', 'Egypt', 'Ethiopia', 'Gabon',
#        'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mauritania',
#        'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger',
#        'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal',
#        'Sierra Leone', 'South Africa', 'Sudan', 'Swaziland', 'Togo',
#        'Tunisia', 'Uganda', 'United Republic of Tanzania', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
f_prod.query('Country == "Cabo Verde"').Value.sum()
# Out:
# 1658

# %%
f_prod.groupby('Country')[['Value','Item']].sum()
# Out:
#                                Value
# Country
# Algeria                       188650
# Angola                        195499
# Benin                          88072
# Botswana                        4808
# Burkina Faso                  100129
# Cabo Verde                      1658
# Cameroon                      197670
# Central African Republic       24921
# Chad                           45078
# Congo                          25791
# Cote d'Ivoire                 182486
# Djibouti                         666
# Egypt                         877498
# Ethiopia                      350693
# Gabon                          13566
# Gambia                          4699
# Ghana                         295004
# Guinea                         66848
# Guinea-Bissau                   7296
# Kenya                         256872
# Lesotho                         3785
# Liberia                        14657
# Madagascar                    133071
# Malawi                        153717
# ...

# %%
f_prod.query('Year == 2004').Value.sum()
# Out:
# 663006

# %%
f_prod.groupby('Year')[['Value']].sum()
# Out:
#        Value
# Year
# 2004  663006
# 2005  691257
# 2006  718602
# 2007  705659
# 2008  736804
# 2009  746870
# 2010  786466
# 2011  812214
# 2012  841667
# 2013  872571

# %%
f_prod.groupby('Item')[['Value']].sum()
# Out:
#                                    Value
# Item
# Alcohol, Non-Food                   3652
# Apples and products                21706
# Aquatic Animals, Others               13
# Aquatic Plants                      1378
# Bananas                           153785
# Barley and products                59315
# Beans                              40762
# Beer                               92630
# Beverages, Alcoholic                5982
# Beverages, Fermented              227037
# Bovine Meat                        53367
# Butter, Ghee                        2793
# Cassava and products             1118948
# Cephalopods                         1286
# Cereals, Other                     41291
# Citrus, Other                      45655
# Cloves                               249
# Cocoa Beans and products           28507
# Coconut Oil                         1108
# Coconuts - Incl Copra              18831
# Coffee and products                 9291
# Cottonseed                         25222
# ...

# %%
## In what year was food produced the most

c = f_prod.groupby("Year")[['Value']].sum().reset_index()

fig, ax = plt.subplots(figsize=(12, 7) )
hbars = ax.bar(c.Year, c.Value, align='center',width =0.5)
ax.bar_label(hbars, labels=c.Value,
                 rotation=90, padding=10, fontsize=12.5)
ax.set (yticklabels= []);
plt.xlabel('Year', fontsize=15)
plt.ylabel('Food Produced (kilotons)', fontsize=15)
plt.title('Total Food Produced For Each Year ', fontsize=15);

# %%
total_prod = f_prod.groupby(['Country','Year'])['Value'].sum().reset_index()

# %%
total_prod

# %%
f_prod.groupby('Value')['Year',].max().reset_index()
# Out:
#       Value  Year
# 0         0  2013
# 1         1  2013
# 2         2  2013
# 3         3  2013
# 4         4  2013
# ...     ...   ...
# 2129  44582  2008
# 2130  45721  2006
# 2131  52403  2011
# 2132  53000  2013
# 2133  54000  2012
#
# [2134 rows x 2 columns]

# %%
total_supply = f_supp

# %%
total_supply
# Out:
#                          Country  Year  Value
# 0                        Algeria  2004   2987
# 1                        Algeria  2005   2958
# 2                        Algeria  2006   3047
# 3                        Algeria  2007   3041
# 4                        Algeria  2008   3048
# 5                        Algeria  2009   3110
# 6                        Algeria  2010   3142
# 7                        Algeria  2011   3217
# 8                        Algeria  2012   3272
# 9                        Algeria  2013   3296
# 10                        Angola  2004   2030
# 11                        Angola  2005   2077
# 12                        Angola  2006   2119
# 13                        Angola  2007   2173
# 14                        Angola  2008   2245
# 15                        Angola  2009   2303
# 16                        Angola  2010   2345
# 17                        Angola  2011   2407
# 18                        Angola  2012   2384
# ...

# %%
val = total_supply.Value
val
# Out:
# 0      2987
# 1      2958
# 2      3047
# 3      3041
# 4      3048
# 5      3110
# 6      3142
# 7      3217
# 8      3272
# 9      3296
# 10     2030
# 11     2077
# 12     2119
# 13     2173
# 14     2245
# 15     2303
# 16     2345
# 17     2407
# 18     2384
# 19     2473
# 20     2461
# 21     2435
# 22     2450
# 23     2564
# 24     2521
# 25     2565
# 26     2555
# 27     2598
# 28     2610
# 29     2619
# 30     2191
# 31     2198
# 32     2150
# 33     2166
# 34     2184
# 35     2199
# 36     2234
# 37     2273
# 38     2342
# 39     2326
# 40     2505
# 41     2463
# 42     2559
# 43     2546
# 44     2588
# 45     2639
# 46     2681
# 47     2664
# 48     2707
# 49     2720
# 50     2523
# 51     2517
# 52     2513
# 53     2574
# 54     2540
# 55     2558
# 56     2524
# 57     2566
# 58     2590
# 59     2609
# 60     2246
# 61     2311
# 62     2354
# 63     2378
# 64     2446
# 65     2492
# 66     2510
# 67     2573
# 68     2622
# 69     2671
# 70     1989
# ...

# %%
total_prod['Supplied_value'] =  val

# %%
total_prod.rename(columns={'Value': 'value_produced'}, inplace=True)
total_prod.rename(columns={'Supplied_value': 'value_supplied'}, inplace=True)

# %%
food = total_prod.copy()

# %%
food
# Out:
#                          Country  Year  value_produced  value_supplied
# 0                        Algeria  2004           15536            2987
# 1                        Algeria  2005           15667            2958
# 2                        Algeria  2006           16417            3047
# 3                        Algeria  2007           14763            3041
# 4                        Algeria  2008           13841            3048
# 5                        Algeria  2009           19820            3110
# 6                        Algeria  2010           20263            3142
# 7                        Algeria  2011           21778            3217
# 8                        Algeria  2012           24206            3272
# 9                        Algeria  2013           26359            3296
# 10                        Angola  2004           13028            2030
# 11                        Angola  2005           13811            2077
# ...

# %%
d = food.groupby("Country")[['value_produced']].sum().reset_index()

# %%
y = food.groupby("Country")[['value_produced','value_supplied']].sum().reset_index()

# %%
u = y.sort_values(by='value_produced')
v= y.sort_values(by='value_supplied')

# %%
d.plot(x="Country", y=["value_produced"],
       kind="bar", width = 0.8, figsize = (15,10));
plt.title('Average budget, revenue and profit over the years by genres '.title(),
         fontsize=15)
plt.xlabel('Genre', fontsize=15)
plt.ylabel('Average', fontsize=15);
plt.xticks( fontsize=12);

# %%
y.plot(x="Country", y=["value_produced", 'value_supplied'],
       kind="bar", width = 0.8, figsize = (15,10));
plt.title('Average budget, revenue and profit over the years by genres '.title(),
         fontsize=15)
plt.xlabel('food Production and Supply', fontsize=15)
plt.ylabel('Quatity', fontsize=15);
plt.xticks( fontsize=12);

# %%
u.plot(x="Country", y=[ 'value_produced'],
       kind="barh", width = 0.8, figsize = (13,10));
plt.title('Total Food production by each countries from 2004-2013'.title(),
         fontsize=15)
plt.xlabel('Total Value Produced (kilotons)', fontsize=15)
plt.ylabel('Countries', fontsize=15);
plt.xticks( fontsize=12);
plt.bar_label(hbars, labels=u.value_produced,
                 rotation=0, padding=10, fontsize=12.5);

plt.legend(loc='lower right');

# %%
 
v.plot(x="Country", y=[ 'value_supplied'],
       kind="barh", width = 0.8, figsize = (13,10));
plt.title('Total Food supplied by each countries from 2004-2013'.title(),
         fontsize=15)
plt.xlabel('Total Value Supplied (kcal/person/day)', fontsize=15)
plt.ylabel('Countries', fontsize=15);
plt.xticks( fontsize=12);


plt.legend(loc='lower right');

# %%
u
# Out:
#                         Country  value_produced  value_supplied
# 11                     Djibouti             666           24165
# 33        Sao Tome and Principe            1152           24462
# 5                    Cabo Verde            1658           25514
# 20                      Lesotho            3785           25588
# 15                       Gambia            4699           25695
# 3                      Botswana            4808           22263
# 18                Guinea-Bissau            7296           22963
# 25                   Mauritania           10039           27443
# 14                        Gabon           13566           27299
# 29                      Namibia           14197           21602
# 21                      Liberia           14657           21827
# 7      Central African Republic           24921           20719
# 9                         Congo           25791           21530
# 39                         Togo           32155           23339
# ...

# %%
u.plot(x="Country", y=[ 'value_supplied'],
       kind="barh", width = 0.8, figsize = (13,8));
plt.title('Total supply from each countries from 2004-2013'.title(),
         fontsize=15)
plt.xlabel('Total Value Supplied', fontsize=15)
plt.ylabel('countries', fontsize=15);
plt.xticks( fontsize=12);

# %%
    import statsmodels.api as sn
    import scipy  
    #To get the statistacal correlation tbetween the two column
    print(f'correlation between value_produced and value_supplied is' , scipy.stats.pearsonr(y['value_produced'],y['value_supplied'])[0])
    sb.set_theme(color_codes=True)
    #To plot a scatter chart
    sb.regplot(x='value_produced', y= 'value_supplied', data=y, marker="+", 
                scatter_kws={"s": 50 });
    sb.set(rc={'figure.figsize':(7,5)})
    plt.xlabel('value_produced'.title(), fontsize=12)
    plt.ylabel('value_supplied'.title(), fontsize=12);
    plt.title(f'relationship between value_supplied and value_produced'.title(), fontsize=12);
# Out:
# correlation between value_produced and value_supplied is 0.30702274978980576

# %%
d = f_prod.query('Item == "Oats" and Year == 2010')
d
# Out:
#             Country  Item  Year  Value
# 46          Algeria  Oats  2010     88
# 6406       Ethiopia  Oats  2010     48
# 7746          Ghana  Oats  2010      0
# 9286          Kenya  Oats  2010      3
# 10026       Lesotho  Oats  2010      0
# 13186       Morocco  Oats  2010     37
# 17816  South Africa  Oats  2010     34
# 20056       Tunisia  Oats  2010      2
# 22516      Zimbabwe  Oats  2010      1

# %%
e = f_supp.query('Year in [2004,2005,2006]')

# %%
e.groupby("Country")[['Value']].sum().reset_index().sort_values(by ='Value')
# Out:
#                         Country  Value
# 43                       Zambia   5577
# 13                     Ethiopia   5827
# 7      Central African Republic   6044
# 32                       Rwanda   6050
# 8                          Chad   6082
# 22                   Madagascar   6123
# 44                     Zimbabwe   6184
# 28                   Mozambique   6208
# 1                        Angola   6226
# 35                 Sierra Leone   6261
# 19                        Kenya   6344
# 21                      Liberia   6368
# 42  United Republic of Tanzania   6373
# 9                         Congo   6449
# 3                      Botswana   6539
# 23                       Malawi   6626
# 11                     Djibouti   6715
# 29                      Namibia   6741
# 39                         Togo   6767
# 18                Guinea-Bissau   6783
# 34                      Senegal   6795
# 37                        Sudan   6898
# 6                      Cameroon   6911
# ...

# %%
dfg = f_prod.query('Item == "Rice (Milled Equivalent)"' )

# %%
dfg.groupby("Country")[['Value']].sum().reset_index().sort_values(by ='Value', ascending = False)
# Out:
#                         Country  Value
# 9                         Egypt  40370
# 26                      Nigeria  26964
# 18                   Madagascar  26118
# 35  United Republic of Tanzania  10956
# 14                       Guinea  10400
# 20                         Mali  10371
# 8                 Cote d'Ivoire   6439
# 29                 Sierra Leone   6038
# 28                      Senegal   2462
# 13                        Ghana   2443
# 17                      Liberia   1602
# 3                  Burkina Faso   1265
# 34                       Uganda   1234
# 6                          Chad   1167
# 24                   Mozambique   1110
# 15                Guinea-Bissau   1030
# 2                         Benin    850
# 4                      Cameroon    767
# 21                   Mauritania    751
# 19                       Malawi    674
# 33                         Togo    653
# 16                        Kenya    504
# 27                       Rwanda    482
# ...
